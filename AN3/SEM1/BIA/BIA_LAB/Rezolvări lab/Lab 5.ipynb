# %% [markdown]
# # Exercitii

# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np
from sklearn.manifold import TSNE
from sklearn.datasets import load_digits
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from time import time

# %% [markdown]
# ### Exercitiul 1

# %%
iris_dataset = load_iris()
X = iris_dataset.data 
y = iris_dataset.target

pca = PCA(n_components=3, random_state=42)
X3D = pca.fit_transform(X)

print(pca.components_)
print(pca.explained_variance_ratio_)

fig = plt.figure()
ax = fig.add_subplot(121, projection='3d')

ax.scatter(X3D[:, 0], X3D[:, 1], X3D[:, 2], c=y, cmap=plt.cm.Set1, edgecolor='k', s=40)
ax.set_xlabel('z_1')
ax.set_ylabel('z_2')
ax.set_zlabel('z_3')
plt.title('3D dataset with PCA')

tsne = TSNE(n_components=3, random_state=42)
X3D_tsne = tsne.fit_transform(X)

ax = fig.add_subplot(122, projection='3d')

ax.scatter(X3D_tsne[:, 0], X3D_tsne[:, 1], X3D_tsne[:, 2], c=y, cmap=plt.cm.Set1, edgecolor='k', s=40)
ax.set_xlabel('z_1')
ax.set_ylabel('z_2')
ax.set_zlabel('z_3')
plt.title('3D dataset with TSNE')
plt.show()
# Out:
# [[ 0.36138659 -0.08452251  0.85667061  0.3582892 ]
#  [ 0.65658877  0.73016143 -0.17337266 -0.07548102]
#  [-0.58202985  0.59791083  0.07623608  0.54583143]]
# [0.92461872 0.05306648 0.01710261]

# %% [markdown]
# ### Exercitiul 2

# %%
digits = load_digits()

X = digits.data
y = digits.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

svm_clf = LinearSVC(C=5, random_state=42)
time1 = time()
svm_clf.fit(X_train, y_train)
time2 = time()

y_test_predicted = svm_clf.predict(X_test)

print("Time for training with all features: ", (time2 - time1))
print("The accuracy score when using all features: ", accuracy_score(y_test_predicted, y_test))

pca = PCA(n_components=20, random_state=42)
X20D = pca.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X20D, y, test_size=0.25, random_state=42)

svm_clf = LinearSVC(C=5, random_state=42)
time1 = time()
svm_clf.fit(X_train, y_train)
time2 = time()

y_test_predicted = svm_clf.predict(X_test)

print("Time for training with 20 features: ", (time2 - time1))
print("The accuracy score when using 20 features: ", accuracy_score(y_test_predicted, y_test))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Time for training with all features:  0.3660893440246582
# The accuracy score when using all features:  0.9377777777777778
# Time for training with 20 features:  0.5451922416687012
# The accuracy score when using 20 features:  0.9422222222222222
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
